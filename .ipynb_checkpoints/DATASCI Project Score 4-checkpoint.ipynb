# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as py
import matplotlib.pyplot as plot
import seaborn as sns
from matplotlib import rc

import matplotlib.mlab as mlab

# %%
pd.set_option("display.max_rows", 100)

# %%
dfMain = pd.read_csv('main.csv', low_memory=False);
#Loads 'main.csv'

# %%
dfMain.columns.values
# Out:
# array(['mainid', 'mainworkgroup', 'maindeviceserial', 'maintransferdate',
#        'androiddescription', 'geopoint_hh_ind', 'geopoint_hhlongitude',
#        'geopoint_hhlatitude', 'geopoint_hhaltitude',
#        'geopoint_hhaccuracy', 'regn', 'prov', 'mun', 'zone', 'brgy',
#        'purok', 'street', 'hnum', 'hcn', 'int_date', 'start_time',
#        'house_type', 'house_type_o', 'nbr', 'roof', 'wall', 'nofw',
#        'nnucfam', 'hpregind', 'uniparind', 'disableind', 'phsize',
#        'water', 'water_o', 'water_dist', 'toil', 'toil_o', 'tenur',
#        'tenur_o', 'imprnt', 'welec', 'elec_company', 'elec_generator',
#        'elec_solar', 'elec_battery', 'elec_source_o', 'elec_source_o_lb',
#        'radio', 'radio_nwacq', 'tv', 'tv_nwacq', 'vplayer',
#        'vplayer_nwacq', 'stereo', 'stereo_nwacq', 'karaoke',
#        'karaoke_nwacq', 'ref', 'ref_nwacq', 'efan', 'efan_nwacq', 'iron',
#        'iron_nwacq', 'stove', 'stove_nwacq', 'wmach', 'wmach_nwacq',
#        'microw', 'microw_nwacq', 'computer', 'computer_nwacq', 'internet',
#        'internet_nwacq', 'celfone', 'celfone_nwacq', 'telefone',
#        'telefone_nwacq', 'airc', 'airc_nwacq', 'sewmach', 'sewmach_nwacq',
#        'car', 'car_nwacq', 'motor', 'motor_nwacq', 'landagri',
#        'landagri_nwacq', 'landres', 'landres_nwacq', 'landcomm',
#        'landcomm_nwacq', 'sofa', 'sofa_nwacq', 'dineset', 'dineset_nwacq',
#        'own_other', 'own_other_o', 'own_other_nwacq', 'insur_house',
#        'insur_house_src', 'insur_house_src_o', 'insur_motor',
#        'insur_motor_src', 'insur_motor_src_o', 'insur_appliance',
#        'insur_appliance_src', 'insur_appliance_src_o', 'garb_collect',
#        'garb_burn', 'garb_comp', 'garb_recycl', 'garb_wsegr', 'garb_cpit',
#        'garb_opit', 'garb_river', 'garb_mgt_o', 'garb_mgt_o_lb',
#        'garb_collector', 'garb_collector_o', 'freq_garb_coll',
#        'freq_garb_coll_o', 'cropind', 'cropincsh', 'cropinknd',
#        'poultind', 'pouincsh', 'pouinknd', 'fishind', 'fishincsh',
#        'fishinknd', 'forind', 'forincsh', 'forinknd', 'salind',
#        'salincsh', 'salinknd', 'manind', 'manincsh', 'maninknd',
#        'servind', 'servincsh', 'servinknd', 'trnind', 'trnincsh',
#        'trninknd', 'minind', 'minincsh', 'mininknd', 'cnsind', 'cnsincsh',
#        'cnsinknd', 'eothind', 'eoincsh', 'eoinknd', 'etotcsh', 'etotknd',
#        'wagcsh', 'wagknd', 'agscsh', 'agsknd', 'ofwcsh', 'ofwknd',
#        'supfcsh', 'supfknd', 'suprcsh', 'suprknd', 'rentvcsh', 'rentvknd',
#        'intrcsh', 'intrknd', 'pencsh', 'penknd', 'divcsh', 'divknd',
#        'othscsh', 'othsknd', 'othstotcsh', 'othstotknd', 'imprnttot',
#        'totincsh', 'totinknd', 'totin', 'nalp', 'ncrop', 'agriequip1',
#        'agriequip1_nown', 'agriequip2', 'agriequip2_nown', 'agriequip3',
#        'agriequip3_nown', 'agriequip4', 'agriequip4_nown', 'agriequip5',
#        'agriequip5_nown', 'agriequip6', 'agriequip6_nown', 'agriequip7',
#        'agriequip7_nown', 'agriequip8', 'agriequip8_nown', 'agriequip9',
#        'agriequip9_nown', 'agriequip10', 'agriequip10_nown',
#        'agriequip11', 'agriequip11_nown', 'agriequip12',
#        'agriequip12_nown', 'agriequip13', 'agriequip13_nown',
#        'agriequip14', 'agriequip14_nown', 'agriequip15',
#        'agriequip15_nown', 'agriequip16', 'agriequip16_nown',
#        'agriequip17', 'agriequip17_nown', 'agriequip18',
#        'agriequip18_nown', 'agriequip18_o', 'live_a_hog',
#        'live_a_hog_vol', 'live_a_goat', 'live_a_goat_vol',
#        'live_a_carabao', 'live_a_carabao_vol', 'live_a_cow',
#        'live_a_cow_vol', 'live_a_chicken', 'live_a_chicken_vol',
#        'live_a_duck', 'live_a_duck_vol', 'live_a_others',
#        'live_a_others_o', 'live_a_others_vol', 'meat_hog', 'meat_hog_vol',
#        'meat_goat', 'meat_goat_vol', 'meat_carabao', 'meat_carabao_vol',
#        'meat_cow', 'meat_cow_vol', 'meat_chicken', 'meat_chicken_vol',
#        'meat_duck', 'meat_duck_vol', 'meat_others', 'meat_others_o',
#        'meat_others_vol', 'milk_goat', 'milk_goat_vol', 'milk_carabao',
#        'milk_carabao_vol', 'milk_cow', 'milk_cow_vol', 'milk_others',
#        'milk_others_o', 'milk_others_vol', 'egg_chicken',
#        'egg_chicken_vol', 'egg_duck', 'egg_duck_vol', 'egg_others',
#        'egg_others_o', 'egg_others_vol', 'oani_ind', 'oani_txt',
#        'oani_hog', 'oani_hog_vol', 'oani_goat', 'oani_goat_vol',
#        'oani_carabao', 'oani_carabao_vol', 'oani_cow', 'oani_cow_vol',
#        'oani_chicken', 'oani_chicken_vol', 'oani_duck', 'oani_duck_vol',
#        'oani_others', 'oani_others_o', 'oani_others_vol', 'catch_fish',
#        'cul_fish', 'catch_fish_loc', 'boat1', 'boat1_own', 'boat2',
#        'boat2_own', 'boat3', 'boat3_own', 'boat4', 'boat4_own', 'boat5',
#        'boat5_own', 'naquaequip', 'fishpond', 'fishpen', 'fishcage',
#        'seaweedfarm', 'oysterfarm', 'musselfarm', 'fishtank', 'hatchery',
#        'aquafarm_o', 'aquafarm_o_txt', 'naquani', 'maxyr_resid',
#        'yrs_in_cropind', 'u_amt_harv', 'u_low_harv', 'u_low_harv_o_lb',
#        'u_chng_scrop', 'u_chng_scrop_y', 'u_chng_scrop_y_o_lb',
#        'u_chng_pcrop', 'u_chng_pcrop_y', 'u_chng_pcrop_y_o_lb',
#        'irfa_crop', 'irfa_crop_src', 'irfa_crop_src_o', 'irfa_agriequip',
#        'irfa_agriequip_src', 'irfa_agriequip_src_o', 'yrs_in_lstockind',
#        'u_amt_lve', 'u_low_lve', 'u_low_lve_o_lb', 'irfa_anim',
#        'irfa_anim_src', 'irfa_anim_src_o', 'yrs_in_fishind', 'u_amt_fish',
#        'u_low_fish', 'u_low_fish_o_lb', 'irfa_fish', 'irfa_fish_src',
#        'irfa_fish_src_o', 'temp_humid', 'elec_loss', 'sea_level',
#        'water_supply', 'low_wsupp', 'low_wsupp_o_lb', 'flood_freq',
#        'flood_duration', 'flood_duration_12', 'drought',
#        'drought_duration', 'evac_mveout', 'evac_ymveout',
#        'evac_ymveout_o', 'evac_trans', 'evac_cntr', 'evac_cntr_o_lb',
#        'calam1', 'calam1_hwmny', 'calam1_aid', 'calam1_hus_aid',
#        'calam1_hus_aid_o', 'calam2', 'calam2_hwmny', 'calam2_aid',
#        'calam2_hus_aid', 'calam2_hus_aid_o', 'calam3', 'calam3_hwmny',
#        'calam3_aid', 'calam3_hus_aid', 'calam3_hus_aid_o', 'calam4',
#        'calam4_hwmny', 'calam4_aid', 'calam4_hus_aid', 'calam4_hus_aid_o',
#        'calam5', 'calam5_hwmny', 'calam5_aid', 'calam5_hus_aid',
#        'calam5_hus_aid_o', 'calam6', 'calam6_hwmny', 'calam6_aid',
#        'calam6_hus_aid', 'calam6_hus_aid_o', 'calam7', 'calam7_hwmny',
#        'calam7_aid', 'calam7_hus_aid', 'calam7_hus_aid_o', 'calam8',
#        'calam8_hwmny', 'calam8_aid', 'calam8_hus_aid', 'calam8_hus_aid_o',
#        'calam9', 'calam9_hwmny', 'calam9_aid', 'calam9_hus_aid',
#        'calam9_hus_aid_o', 'calam10', 'calam10_hwmny', 'calam10_aid',
#        'calam10_hus_aid', 'calam10_hus_aid_o', 'calam11', 'calam11_o',
#        'calam11_hwmny', 'calam11_aid', 'calam11_hus_aid',
#        'calam11_hus_aid_o', 'disas_prep', 'dp_kit1', 'dp_kit1_xpiry',
#        'dp_kit2', 'dp_kit2_xpiry', 'dp_kit3', 'dp_kit4', 'dp_kit5',
#        'dp_kit6', 'dp_kit7', 'dp_kit8', 'dp_kit9', 'dp_kit10', 'dp_kit11',
#        'dp_kit12', 'dp_kit13', 'dp_kit13_o', 'dp_kit13_xpiry', 'fshort',
#        'fsmonth_1', 'fsdays_1', 'fsmonth_2', 'fsdays_2', 'fsmonth_3',
#        'fsdays_3', 'prevmind', 'ndeath', 'prog_slp', 'prog_slp_nmem',
#        'prog_slp_impl', 'prog_slp_impl_o', 'prog_fudforsch',
#        'prog_fudforsch_nmem', 'prog_fudforsch_impl',
#        'prog_fudforsch_impl_o', 'prog_fudforwrk', 'prog_fudforwrk_nmem',
#        'prog_fudforwrk_impl', 'prog_fudforwrk_impl_o', 'prog_cshforwrk',
#        'prog_cshforwrk_nmem', 'prog_cshforwrk_impl',
#        'prog_cshforwrk_impl_o', 'prog_spisc', 'prog_spisc_nmem',
#        'prog_spisc_impl', 'prog_spisc_impl_o', 'prog_cct',
#        'prog_cct_nmem', 'prog_cct_impl', 'prog_cct_impl_o', 'prog_arcdp',
#        'prog_arcdp_nmem', 'prog_arcdp_impl', 'prog_arcdp_impl_o',
#        'prog_cbep', 'prog_cbep_nmem', 'prog_cbep_impl',
#        'prog_cbep_impl_o', 'prog_phiheal_ofw', 'prog_phiheal_ofw_nmem',
#        'prog_phiheal_empl', 'prog_phiheal_empl_nmem',
#        'prog_phiheal_indiv', 'prog_phiheal_indiv_nmem',
#        'prog_phiheal_spon', 'prog_phiheal_spon_nmem',
#        'prog_phiheal_spon_impl', 'prog_phiheal_spon_impl_o',
#        'prog_phiheal_life', 'prog_phiheal_life_nmem', 'nprog', 'end_time',
#        'Unnamed: 486', 'Unnamed: 487', 'Unnamed: 488'], dtype=object)

# %%
dfMain = dfMain.filter(['mainid','brgy','roof','wall']);
# Filters the dataframe to show only the relevant columns for this scoring phase

dfMain
# Out:
#         mainid  brgy  roof  wall
# 0      1061066   186     4     4
# 1       555683    69     1     1
# 2      8611889     1     1     1
# 3       299398   165     4     4
# 4       136921   135     6     6
# 5      3842267    43     4     4
# 6       899855   201     1     1
# 7       235953   190     1     1
# 8      1591438    47     4     4
# 9      1053432   130     1     1
# 10     1112848   171     1     1
# 11     2728227   159     2     1
# 12       98326    72     1     1
# 13     1955060    40     1     1
# 14     1352565   129     1     1
# 15     7317935   179     1     1
# 16     7320712   139     1     1
# 17      129550   169     1     1
# 18     7320094   159     1     1
# 19     1348436   128     1     1
# 20      194394   170     1     4
# 21     7320805   183     1     1
# 22     2555876    37     1     1
# 23     2880362    49     1     1
# 24     1355289    65     1     1
# 25     3166204   183     1     1
# 26     7320136   190     1     1
# 27      899860   201     1     1
# 28      990548    94     1     1
# 29      234239   165     1     1
# 30     1130117    78     2     2
# 31     3649015    75     1     2
# 32     3528508     2     1     1
# 33     3528491     2     1     1
# 34     3528560     2     1     1
# 35     3528494     2     1     1
# 36     3528501     2     1     1
# 37     2922043    86     1     1
# 38     3528540     2     1     1
# 39     3528502     2     1     1
# 40     3528575     2     1     1
# 41     3528516     2     1     1
# 42     3528514     2     1     1
# 43     3528640     2     1     1
# 44     3528573     2     1     1
# 45     3528641     2     1     1
# 46     3528677     2     1     1
# 47     3528703     2     1     1
# 48     3528520     2     1     1
# 49     3528510     2     1     1
# ...        ...   ...   ...   ...
# 59516  4057631   184     1     1
# 59517  4057633   184     1     1
# 59518  4057634   184     4     4
# 59519  4057637   184     4     4
# 59520  4057638   184     4     4
# 59521  4057639   184     4     4
# 59522  4057640   184     4     4
# 59523  4057740   184     1     1
# 59524  4057641   184     1     1
# 59525  4057643   184     1     1
# 59526  4057645   184     4     4
# 59527  4057650   184     1     1
# 59528  4057653   184     1     1
# 59529  4057657   184     4     4
# 59530  4057665   184     1     1
# 59531  4057679   184     1     1
# 59532  4057682   184     1     1
# 59533  4057686   184     1     1
# 59534  4057700   184     1     1
# 59535  4057709   184     4     4
# 59536  4057712   184     4     4
# 59537  3483181   184     1     1
# 59538  2324874    28     1     1
# 59539   160554   175     1     1
# 59540  3646113    74     1     1
# 59541  3889213   201     1     1
# 59542  3648868    72     1     1
# 59543   151199   172     4     4
# 59544  3027315    96     1     1
# 59545  3356417   201     1     1
# 59546  1554169   201     5     5
# 59547  1368909    61     1     4
# 59548  1521428   185     1     1
# 59549  1525475   185     1     1
# 59550  2765090   145     1     1
# 59551  1987450    98     1     1
# 59552  1779354   138     1     1
# 59553  2710602   191     1     1
# 59554  1106960   201     1     1
# 59555   899178   192     1     1
# 59556   699764   192     1     1
# 59557   699743   192     1     1
# 59558   874688   192     4     4
# 59559   839247   192     4     4
# 59560  2073527   194     4     4
# 59561  3335279   187     4     4
# 59562   578279   197     1     1
# 59563   486916   189     4     4
# 59564  3026228   183     1     1
# 59565  1765944    46     1     1
#
# [59566 rows x 4 columns]

# %%
divisor = 1 / 6
print(divisor)

for i, row in dfMain.iterrows():
    roofScore = 0
    wallScore = 0
    if (row['roof'] == 1) :
        roofScore = divisor * 6
    elif (row['roof'] == 2) :
        roofScore = divisor * 4
    elif (row['roof'] == 3) :
        roofScore = divisor * 1
    elif (row['roof'] == 4) :
        roofScore = divisor * 5
    elif (row['roof'] == 5) :
        roofScore = divisor * 3
    elif (row['roof'] == 6) :
        roofScore = divisor * 2
        
    if (row['wall'] == 1) :
        wallScore = divisor * 6
    elif (row['wall'] == 2) :
        wallScore = divisor * 4
    elif (row['wall'] == 3) :
        wallScore = divisor * 1
    elif (row['wall'] == 4) :
        wallScore = divisor * 5
    elif (row['wall'] == 5) :
        wallScore = divisor * 3
    elif (row['wall'] == 6) :
        wallScore = divisor * 2
    
    dfMain.at[i,'finalScore'] = (roofScore + wallScore) / 2

dfMain
# Out:
# 0.16666666666666666
#         mainid  brgy  roof  wall  finalScore
# 0      1061066   186     4     4    0.833333
# 1       555683    69     1     1    1.000000
# 2      8611889     1     1     1    1.000000
# 3       299398   165     4     4    0.833333
# 4       136921   135     6     6    0.333333
# 5      3842267    43     4     4    0.833333
# 6       899855   201     1     1    1.000000
# 7       235953   190     1     1    1.000000
# 8      1591438    47     4     4    0.833333
# 9      1053432   130     1     1    1.000000
# 10     1112848   171     1     1    1.000000
# 11     2728227   159     2     1    0.833333
# 12       98326    72     1     1    1.000000
# 13     1955060    40     1     1    1.000000
# 14     1352565   129     1     1    1.000000
# 15     7317935   179     1     1    1.000000
# 16     7320712   139     1     1    1.000000
# 17      129550   169     1     1    1.000000
# 18     7320094   159     1     1    1.000000
# 19     1348436   128     1     1    1.000000
# 20      194394   170     1     4    0.916667
# 21     7320805   183     1     1    1.000000
# 22     2555876    37     1     1    1.000000
# 23     2880362    49     1     1    1.000000
# 24     1355289    65     1     1    1.000000
# 25     3166204   183     1     1    1.000000
# 26     7320136   190     1     1    1.000000
# 27      899860   201     1     1    1.000000
# 28      990548    94     1     1    1.000000
# 29      234239   165     1     1    1.000000
# 30     1130117    78     2     2    0.666667
# 31     3649015    75     1     2    0.833333
# 32     3528508     2     1     1    1.000000
# 33     3528491     2     1     1    1.000000
# 34     3528560     2     1     1    1.000000
# 35     3528494     2     1     1    1.000000
# 36     3528501     2     1     1    1.000000
# 37     2922043    86     1     1    1.000000
# 38     3528540     2     1     1    1.000000
# 39     3528502     2     1     1    1.000000
# 40     3528575     2     1     1    1.000000
# 41     3528516     2     1     1    1.000000
# 42     3528514     2     1     1    1.000000
# 43     3528640     2     1     1    1.000000
# 44     3528573     2     1     1    1.000000
# 45     3528641     2     1     1    1.000000
# 46     3528677     2     1     1    1.000000
# 47     3528703     2     1     1    1.000000
# 48     3528520     2     1     1    1.000000
# 49     3528510     2     1     1    1.000000
# ...        ...   ...   ...   ...         ...
# 59516  4057631   184     1     1    1.000000
# 59517  4057633   184     1     1    1.000000
# 59518  4057634   184     4     4    0.833333
# 59519  4057637   184     4     4    0.833333
# 59520  4057638   184     4     4    0.833333
# 59521  4057639   184     4     4    0.833333
# 59522  4057640   184     4     4    0.833333
# 59523  4057740   184     1     1    1.000000
# 59524  4057641   184     1     1    1.000000
# 59525  4057643   184     1     1    1.000000
# 59526  4057645   184     4     4    0.833333
# 59527  4057650   184     1     1    1.000000
# 59528  4057653   184     1     1    1.000000
# 59529  4057657   184     4     4    0.833333
# 59530  4057665   184     1     1    1.000000
# 59531  4057679   184     1     1    1.000000
# 59532  4057682   184     1     1    1.000000
# 59533  4057686   184     1     1    1.000000
# 59534  4057700   184     1     1    1.000000
# 59535  4057709   184     4     4    0.833333
# 59536  4057712   184     4     4    0.833333
# 59537  3483181   184     1     1    1.000000
# 59538  2324874    28     1     1    1.000000
# 59539   160554   175     1     1    1.000000
# 59540  3646113    74     1     1    1.000000
# 59541  3889213   201     1     1    1.000000
# 59542  3648868    72     1     1    1.000000
# 59543   151199   172     4     4    0.833333
# 59544  3027315    96     1     1    1.000000
# 59545  3356417   201     1     1    1.000000
# 59546  1554169   201     5     5    0.500000
# 59547  1368909    61     1     4    0.916667
# 59548  1521428   185     1     1    1.000000
# 59549  1525475   185     1     1    1.000000
# 59550  2765090   145     1     1    1.000000
# 59551  1987450    98     1     1    1.000000
# 59552  1779354   138     1     1    1.000000
# 59553  2710602   191     1     1    1.000000
# 59554  1106960   201     1     1    1.000000
# 59555   899178   192     1     1    1.000000
# 59556   699764   192     1     1    1.000000
# 59557   699743   192     1     1    1.000000
# 59558   874688   192     4     4    0.833333
# 59559   839247   192     4     4    0.833333
# 59560  2073527   194     4     4    0.833333
# 59561  3335279   187     4     4    0.833333
# 59562   578279   197     1     1    1.000000
# 59563   486916   189     4     4    0.833333
# 59564  3026228   183     1     1    1.000000
# 59565  1765944    46     1     1    1.000000
#
# [59566 rows x 5 columns]

# %%
arrayBrgyScores = dfMain.groupby('brgy')['finalScore'].mean()

arrayBrgyScores
# Out:
# brgy
# 1      0.892857
# 2      0.996560
# 3      0.976190
# 4      0.992891
# 5      0.998645
# 6      0.999150
# 7      0.872093
# 8      0.883065
# 9      0.996914
# 10     0.868736
# 11     0.898219
# 12     0.686971
# 13     0.741337
# 14     0.905782
# 15     0.968099
# 16     0.825442
# 17     1.000000
# 18     0.991636
# 19     0.986301
# 20     0.986538
# 21     0.941214
# 22     0.966667
# 23     0.958561
# 24     0.884615
# 25     0.930000
# 26     0.895833
# 27     0.938272
# 28     0.889671
# 29     0.500000
# 30     0.757022
# 31     0.711538
# 33     0.991170
# 34     0.997711
# 35     0.999740
# 36     1.000000
# 37     0.999105
# 38     0.827094
# 40     1.000000
# 41     0.987179
# 42     0.998553
# 43     0.987624
# 44     0.975556
# 46     0.962605
# 47     0.990893
# 48     0.994949
# 49     1.000000
# 50     0.994048
# 51     0.859742
# 52     1.000000
# 54     0.612745
#          ...
# 152    0.906863
# 153    0.833587
# 154    0.832036
# 155    0.994152
# 156    0.765422
# 157    0.843149
# 158    0.992608
# 159    0.979167
# 160    0.998925
# 161    0.943203
# 162    0.935743
# 163    0.716667
# 164    0.995527
# 165    0.888330
# 166    0.992297
# 167    0.995370
# 168    0.996528
# 169    0.914796
# 170    0.916667
# 171    0.982796
# 172    0.910316
# 173    0.941300
# 174    0.986902
# 175    0.977427
# 176    0.666667
# 177    0.904440
# 178    0.880240
# 179    0.803760
# 180    0.937875
# 181    0.906055
# 182    0.967854
# 183    0.959516
# 184    0.819444
# 185    0.942428
# 186    0.784466
# 187    0.830596
# 188    0.898936
# 189    0.887876
# 190    0.897991
# 191    0.981481
# 192    0.955807
# 193    0.954260
# 194    0.889472
# 195    0.953380
# 196    0.855442
# 197    0.970721
# 198    0.964623
# 199    0.990236
# 200    0.926084
# 201    0.935643
# Name: finalScore, Length: 176, dtype: float64

# %%
#Top20
arrayBrgyScorestop20 = dfMain.groupby('brgy')['finalScore'].mean().reset_index()

arrayBrgyScorestop20 = arrayBrgyScorestop20.sort_values('finalScore', ascending=False).head(20)

arrayBrgyScorestop20
# Out:
#      brgy  finalScore
# 96    114    1.000000
# 52     58    1.000000
# 37     40    1.000000
# 45     49    1.000000
# 95    113    1.000000
# 16     17    1.000000
# 48     52    1.000000
# 50     56    1.000000
# 115   141    1.000000
# 74     84    1.000000
# 84     99    1.000000
# 34     36    1.000000
# 33     35    0.999740
# 102   128    0.999396
# 5       6    0.999150
# 114   140    0.999141
# 35     37    0.999105
# 112   138    0.999028
# 134   160    0.998925
# 83     98    0.998911

# %%
#Bottom20
arrayBrgyScoresbot20 = dfMain.groupby('brgy')['finalScore'].mean().reset_index()

arrayBrgyScoresbot20 = arrayBrgyScoresbot20.sort_values('finalScore').head(20)

arrayBrgyScoresbot20
# Out:
#      brgy  finalScore
# 28     29    0.500000
# 63     73    0.561667
# 65     75    0.589888
# 49     54    0.612745
# 150   176    0.666667
# 60     68    0.675000
# 64     74    0.677704
# 61     69    0.683211
# 11     12    0.686971
# 30     31    0.711538
# 137   163    0.716667
# 12     13    0.741337
# 68     78    0.747126
# 118   144    0.756361
# 29     30    0.757022
# 130   156    0.765422
# 122   148    0.766098
# 160   186    0.784466
# 73     83    0.787651
# 109   135    0.796692

# %%
#Bar Graph for all
arrayBrgyScores.plot(figsize=(20, 10), kind='bar', grid=True, align='center', width=0.5, stacked=True)
plot.legend()
plot.show()

# %%
#Bar Graph for bottom 20
arrayBrgyScoresbot20['finalScore'].plot(figsize=(20, 10), kind='bar', grid=True, align='center', width=0.5, stacked=True)
plot.legend()
plot.show()

# %%
#Bar Graph for top 20
arrayBrgyScorestop20['finalScore'].plot(figsize=(20, 10), kind='bar', grid=True, align='center', width=0.5, stacked=True)
plot.legend()
plot.show()
