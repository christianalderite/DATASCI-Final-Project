# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as py
import matplotlib.pyplot as plot
import seaborn as sns
from matplotlib import rc

import matplotlib.mlab as mlab

# %%
dfMain = pd.read_csv('main.csv', low_memory=False);
#Loads 'main.csv'

# %%
dfMain = dfMain.filter(['mainid','brgy','internet','radio','tv','celfone','telefone','car','motor']);
# Filters the dataframe to show only the relevant columns for this scoring phase

dfMain
# Out:
#         mainid  brgy  internet  radio  tv  celfone  telefone  car  motor
# 0      1061066   186         0      0   1        2         0    0      0
# 1       555683    69         0      1   0        2         0    0      0
# 2      8611889     1         0      1   1        1         0    1      0
# 3       299398   165         0      0   0        0         0    0      0
# 4       136921   135         0      1   1        1         0    0      0
# 5      3842267    43         0      0   1        0         0    0      0
# 6       899855   201         1      1   2        3         0    1      1
# 7       235953   190         0      0   1        2         0    0      1
# 8      1591438    47         0      0   1        1         0    0      0
# 9      1053432   130         0      0   1        3         0    0      0
# 10     1112848   171         0      0   1        2         0    0      0
# 11     2728227   159         0      1   1        0         0    0      0
# 12       98326    72         1      1   1        4         1    0      0
# 13     1955060    40         0      0   1        3         0    0      0
# 14     1352565   129         0      0   0        1         0    0      0
# 15     7317935   179         1      1   1        3         1    1      0
# 16     7320712   139         0      0   0        2         0    0      0
# 17      129550   169         0      1   1        3         0    0      0
# 18     7320094   159         0      1   1        4         0    0      1
# 19     1348436   128         0      0   1        2         0    0      0
# 20      194394   170         0      0   0        2         0    0      0
# 21     7320805   183         1      0   1        5         1    3      0
# 22     2555876    37         0      0   1        2         0    0      0
# 23     2880362    49         0      0   1        2         0    0      0
# 24     1355289    65         0      0   1        3         0    2      0
# 25     3166204   183         0      0   0        1         0    0      0
# 26     7320136   190         0      2   2        3         0    0      1
# 27      899860   201         1      1   2        3         0    1      0
# 28      990548    94         1      0   1        0         0    0      0
# 29      234239   165         0      0   1        2         0    0      0
# ...        ...   ...       ...    ...  ..      ...       ...  ...    ...
# 59536  4057712   184         0      0   0        1         0    0      0
# 59537  3483181   184         0      0   0        2         0    0      0
# 59538  2324874    28         0      0   1        2         0    0      0
# 59539   160554   175         0      0   1        4         0    0      0
# 59540  3646113    74         0      0   0        0         0    0      0
# 59541  3889213   201         0      0   1        1         0    0      0
# 59542  3648868    72         0      0   0        1         0    0      0
# 59543   151199   172         0      0   1        4         0    0      0
# 59544  3027315    96         1      0   1        3         0    0      0
# 59545  3356417   201         0      0   1        0         0    0      0
# 59546  1554169   201         0      0   1        2         0    0      0
# 59547  1368909    61         0      1   1        4         0    0      0
# 59548  1521428   185         0      0   1        2         0    0      0
# 59549  1525475   185         0      0   1        2         0    0      0
# 59550  2765090   145         0      1   1        0         0    0      0
# 59551  1987450    98         0      0   2        3         0    0      0
# 59552  1779354   138         0      0   1        4         0    0      1
# 59553  2710602   191         0      0   1        0         0    0      0
# 59554  1106960   201         0      0   1        3         0    0      0
# 59555   899178   192         0      0   1        0         0    0      0
# 59556   699764   192         0      0   1        1         0    0      0
# 59557   699743   192         1      0   1        4         0    0      0
# 59558   874688   192         0      0   1        3         0    0      0
# 59559   839247   192         0      1   1        1         0    0      0
# 59560  2073527   194         0      0   1        2         0    0      0
# 59561  3335279   187         0      0   1        1         0    0      0
# 59562   578279   197         0      0   1        2         0    0      0
# 59563   486916   189         0      1   0        0         0    0      0
# 59564  3026228   183         1      0   1        4         0    0      0
# 59565  1765944    46         1      1   1        3         1    0      0
#
# [59566 rows x 9 columns]

# %%
for i, row in dfMain.iterrows():
    if (row['internet'] > 0) :
        dfMain.at[i,'internet']=1
    if (row['radio'] > 0) :
        dfMain.at[i,'radio']=1
    if (row['tv'] > 0) :
        dfMain.at[i,'tv']=1
    if (row['celfone'] > 0) :
        dfMain.at[i,'celfone']=1
    if (row['telefone'] > 0) :
        dfMain.at[i,'telefone']=1
    if (row['car'] > 0) :
        dfMain.at[i,'car']=1
    if (row['motor'] > 0) :
        dfMain.at[i,'motor']=1

# Changing quantity responses into True or False responses
# If there is one occurence or more it is True, False if none
        
dfMain
# Out:
#         mainid  brgy  internet  radio  tv  celfone  telefone  car  motor
# 0      1061066   186         0      0   1        1         0    0      0
# 1       555683    69         0      1   0        1         0    0      0
# 2      8611889     1         0      1   1        1         0    1      0
# 3       299398   165         0      0   0        0         0    0      0
# 4       136921   135         0      1   1        1         0    0      0
# 5      3842267    43         0      0   1        0         0    0      0
# 6       899855   201         1      1   1        1         0    1      1
# 7       235953   190         0      0   1        1         0    0      1
# 8      1591438    47         0      0   1        1         0    0      0
# 9      1053432   130         0      0   1        1         0    0      0
# 10     1112848   171         0      0   1        1         0    0      0
# 11     2728227   159         0      1   1        0         0    0      0
# 12       98326    72         1      1   1        1         1    0      0
# 13     1955060    40         0      0   1        1         0    0      0
# 14     1352565   129         0      0   0        1         0    0      0
# 15     7317935   179         1      1   1        1         1    1      0
# 16     7320712   139         0      0   0        1         0    0      0
# 17      129550   169         0      1   1        1         0    0      0
# 18     7320094   159         0      1   1        1         0    0      1
# 19     1348436   128         0      0   1        1         0    0      0
# 20      194394   170         0      0   0        1         0    0      0
# 21     7320805   183         1      0   1        1         1    1      0
# 22     2555876    37         0      0   1        1         0    0      0
# 23     2880362    49         0      0   1        1         0    0      0
# 24     1355289    65         0      0   1        1         0    1      0
# 25     3166204   183         0      0   0        1         0    0      0
# 26     7320136   190         0      1   1        1         0    0      1
# 27      899860   201         1      1   1        1         0    1      0
# 28      990548    94         1      0   1        0         0    0      0
# 29      234239   165         0      0   1        1         0    0      0
# ...        ...   ...       ...    ...  ..      ...       ...  ...    ...
# 59536  4057712   184         0      0   0        1         0    0      0
# 59537  3483181   184         0      0   0        1         0    0      0
# 59538  2324874    28         0      0   1        1         0    0      0
# 59539   160554   175         0      0   1        1         0    0      0
# 59540  3646113    74         0      0   0        0         0    0      0
# 59541  3889213   201         0      0   1        1         0    0      0
# 59542  3648868    72         0      0   0        1         0    0      0
# 59543   151199   172         0      0   1        1         0    0      0
# 59544  3027315    96         1      0   1        1         0    0      0
# 59545  3356417   201         0      0   1        0         0    0      0
# 59546  1554169   201         0      0   1        1         0    0      0
# 59547  1368909    61         0      1   1        1         0    0      0
# 59548  1521428   185         0      0   1        1         0    0      0
# 59549  1525475   185         0      0   1        1         0    0      0
# 59550  2765090   145         0      1   1        0         0    0      0
# 59551  1987450    98         0      0   1        1         0    0      0
# 59552  1779354   138         0      0   1        1         0    0      1
# 59553  2710602   191         0      0   1        0         0    0      0
# 59554  1106960   201         0      0   1        1         0    0      0
# 59555   899178   192         0      0   1        0         0    0      0
# 59556   699764   192         0      0   1        1         0    0      0
# 59557   699743   192         1      0   1        1         0    0      0
# 59558   874688   192         0      0   1        1         0    0      0
# 59559   839247   192         0      1   1        1         0    0      0
# 59560  2073527   194         0      0   1        1         0    0      0
# 59561  3335279   187         0      0   1        1         0    0      0
# 59562   578279   197         0      0   1        1         0    0      0
# 59563   486916   189         0      1   0        0         0    0      0
# 59564  3026228   183         1      0   1        1         0    0      0
# 59565  1765944    46         1      1   1        1         1    0      0
#
# [59566 rows x 9 columns]

# %%
dfMain['asset_total'] = dfMain['internet'] + dfMain['radio'] + dfMain['tv'] + dfMain['celfone'] + dfMain['telefone'] + dfMain['car'] + dfMain['motor']
# Adds the total number of True responses for the 7 assets

dfMain['asset_score'] = dfMain['asset_total'] / 7
# Scores the asset ownership of each family by getting the ratio of amount of types of possessed assets over 7.

dfMain
# Out:
#         mainid  brgy  internet  radio  tv  celfone  telefone  car  motor  \
# 0      1061066   186         0      0   1        1         0    0      0
# 1       555683    69         0      1   0        1         0    0      0
# 2      8611889     1         0      1   1        1         0    1      0
# 3       299398   165         0      0   0        0         0    0      0
# 4       136921   135         0      1   1        1         0    0      0
# 5      3842267    43         0      0   1        0         0    0      0
# 6       899855   201         1      1   1        1         0    1      1
# 7       235953   190         0      0   1        1         0    0      1
# 8      1591438    47         0      0   1        1         0    0      0
# 9      1053432   130         0      0   1        1         0    0      0
# 10     1112848   171         0      0   1        1         0    0      0
# 11     2728227   159         0      1   1        0         0    0      0
# 12       98326    72         1      1   1        1         1    0      0
# 13     1955060    40         0      0   1        1         0    0      0
# 14     1352565   129         0      0   0        1         0    0      0
# 15     7317935   179         1      1   1        1         1    1      0
# 16     7320712   139         0      0   0        1         0    0      0
# 17      129550   169         0      1   1        1         0    0      0
# 18     7320094   159         0      1   1        1         0    0      1
# 19     1348436   128         0      0   1        1         0    0      0
# 20      194394   170         0      0   0        1         0    0      0
# 21     7320805   183         1      0   1        1         1    1      0
# 22     2555876    37         0      0   1        1         0    0      0
# 23     2880362    49         0      0   1        1         0    0      0
# 24     1355289    65         0      0   1        1         0    1      0
# 25     3166204   183         0      0   0        1         0    0      0
# 26     7320136   190         0      1   1        1         0    0      1
# 27      899860   201         1      1   1        1         0    1      0
# 28      990548    94         1      0   1        0         0    0      0
# 29      234239   165         0      0   1        1         0    0      0
# ...        ...   ...       ...    ...  ..      ...       ...  ...    ...
# 59536  4057712   184         0      0   0        1         0    0      0
# 59537  3483181   184         0      0   0        1         0    0      0
# 59538  2324874    28         0      0   1        1         0    0      0
# 59539   160554   175         0      0   1        1         0    0      0
# 59540  3646113    74         0      0   0        0         0    0      0
# 59541  3889213   201         0      0   1        1         0    0      0
# 59542  3648868    72         0      0   0        1         0    0      0
# 59543   151199   172         0      0   1        1         0    0      0
# 59544  3027315    96         1      0   1        1         0    0      0
# 59545  3356417   201         0      0   1        0         0    0      0
# 59546  1554169   201         0      0   1        1         0    0      0
# 59547  1368909    61         0      1   1        1         0    0      0
# 59548  1521428   185         0      0   1        1         0    0      0
# 59549  1525475   185         0      0   1        1         0    0      0
# 59550  2765090   145         0      1   1        0         0    0      0
# 59551  1987450    98         0      0   1        1         0    0      0
# 59552  1779354   138         0      0   1        1         0    0      1
# 59553  2710602   191         0      0   1        0         0    0      0
# 59554  1106960   201         0      0   1        1         0    0      0
# 59555   899178   192         0      0   1        0         0    0      0
# 59556   699764   192         0      0   1        1         0    0      0
# 59557   699743   192         1      0   1        1         0    0      0
# 59558   874688   192         0      0   1        1         0    0      0
# 59559   839247   192         0      1   1        1         0    0      0
# 59560  2073527   194         0      0   1        1         0    0      0
# 59561  3335279   187         0      0   1        1         0    0      0
# 59562   578279   197         0      0   1        1         0    0      0
# 59563   486916   189         0      1   0        0         0    0      0
# 59564  3026228   183         1      0   1        1         0    0      0
# 59565  1765944    46         1      1   1        1         1    0      0
#
#        asset_total  asset_score
# 0                2     0.285714
# 1                2     0.285714
# 2                4     0.571429
# 3                0     0.000000
# 4                3     0.428571
# 5                1     0.142857
# 6                6     0.857143
# 7                3     0.428571
# 8                2     0.285714
# 9                2     0.285714
# 10               2     0.285714
# 11               2     0.285714
# 12               5     0.714286
# 13               2     0.285714
# 14               1     0.142857
# 15               6     0.857143
# 16               1     0.142857
# 17               3     0.428571
# 18               4     0.571429
# 19               2     0.285714
# 20               1     0.142857
# 21               5     0.714286
# 22               2     0.285714
# 23               2     0.285714
# 24               3     0.428571
# 25               1     0.142857
# 26               4     0.571429
# 27               5     0.714286
# 28               2     0.285714
# 29               2     0.285714
# ...            ...          ...
# 59536            1     0.142857
# 59537            1     0.142857
# 59538            2     0.285714
# 59539            2     0.285714
# 59540            0     0.000000
# 59541            2     0.285714
# 59542            1     0.142857
# 59543            2     0.285714
# 59544            3     0.428571
# 59545            1     0.142857
# 59546            2     0.285714
# 59547            3     0.428571
# 59548            2     0.285714
# 59549            2     0.285714
# 59550            2     0.285714
# 59551            2     0.285714
# 59552            3     0.428571
# 59553            1     0.142857
# 59554            2     0.285714
# 59555            1     0.142857
# 59556            2     0.285714
# 59557            3     0.428571
# 59558            2     0.285714
# 59559            3     0.428571
# 59560            2     0.285714
# 59561            2     0.285714
# 59562            2     0.285714
# 59563            1     0.142857
# 59564            3     0.428571
# 59565            5     0.714286
#
# [59566 rows x 11 columns]

# %%
dfBrgy1 = dfMain.loc[dfMain.brgy == 1]
dfBrgy1

# Just to check if output is correct, Brgy 1 has 7 respondents with a total of 2.57 score, therefore averaging on 0.367347
# Out:
#         mainid  brgy  internet  radio  tv  celfone  telefone  car  motor  \
# 2      8611889     1         0      1   1        1         0    1      0
# 4207    130766     1         0      0   1        1         0    0      0
# 16399  1057542     1         0      0   1        1         0    0      0
# 20626   120577     1         0      0   1        1         0    0      0
# 21826   254233     1         1      1   1        1         1    0      0
# 21827   254229     1         0      0   0        1         0    0      0
# 57661  3397181     1         0      0   1        1         0    0      0
#
#        asset_total  asset_score
# 2                4     0.571429
# 4207             2     0.285714
# 16399            2     0.285714
# 20626            2     0.285714
# 21826            5     0.714286
# 21827            1     0.142857
# 57661            2     0.285714

# %%
arrayBrgyScores = dfMain.groupby('brgy')['asset_score'].mean()
# Groups the families by brgy and takes the average of their asset score.
# Output is an array, not a dataframe.

#plot.style.use('default')

ax = arrayBrgyScores.plot(kind='barh', figsize=(10, 50), color='#008080',  width=0.8, stacked=True)
ax.invert_yaxis()
plot.title('The Mean Calamity-Useful Assets Ownership Score of Each Baranggay (Ordered by Brgy No.)', y=1.01)
ax.set_ylabel('Baranggay #')
ax.set_xlabel('Score')    
ax.xaxis.set_label_position('top') 
ax.xaxis.tick_top()
for p in ax.patches:
    ax.annotate(str(p.get_width()), (p.get_width() * 1.005, p.get_y() + 0.5))
plot.legend()
plot.show()
# Visualizes baranggays in horizontal fashion ordered by brgy. for better lookup

arrayBrgyScores.sort_values().plot(figsize=(20, 10), color='#008080',kind='bar', align='center', width=0.8, stacked=True)
plot.title('The Mean Calamity-Useful Assets Ownership Score of Each Baranggay (Ordered by Score)')
plot.ylim(0,1)
plot.legend()
plot.show()
# Bar graph of all the college literacy rate per family of each baranggay

arrayBrgyScores.nlargest(10).plot(figsize=(8, 8), kind='bar', color='#008080', align='center', width=0.8, stacked=True)
plot.title('Top 10 Mean Calamity-Useful Assets Ownership Score of Each Baranggay')
plot.ylim(0,1)
plot.legend()
plot.show()
# Bar graph of the top 10 brgys, 

arrayBrgyScores.nsmallest(10).plot(figsize=(8, 8), kind='bar',color='#008080', align='center', width=0.8, stacked=True)
plot.title('Bottom 10 Mean Calamity-Useful Assets Ownership Score of Each Baranggay')
plot.ylim(0,1)
plot.legend()
plot.show()
# Bar graph of the bottom 10 brgys

dfMain[['celfone','tv','radio','internet','motor','telefone','car']].sum().plot(figsize=(8, 8), kind='bar',  align='center', width=0.8, stacked=True)
plot.title('Total of Number of Households per Asset')
plot.legend()
plot.show()
# Bar graph of the total number of each asset of the respondents

# %% [markdown]
# # Calamity Prep Score 2: The Mean Calamity-Useful Assets Ownership of Each Baranggay
#
# Assumptions:
# 1. Based on a study by INSERT AUTHORS AND LINK, having the listed assets (internet, television, radio, telefone, car, motor, celfone) increases the calamity preparedness of a family.
# 2. We found no study ranking or scoring the importance of each asset listed. It is just given that these are important in a calamity. Therefore we were not able to assign a weight to each asset because we cannot assume that a car is more important than a celfone and so on. We assumed that all these items are equally important.
# 3. We assumed that NaN responses indicated NON-OWNERSHIP of the asset.
#
# Explanation:
# 1. In the FIRST BAR GRAPH and SECOND BAR GRAPH, most baranggays fall between the score range of 0.2 to 0.4 when it comes to asset ownership which indicates that most of these families only have 1-3 of the assets listed which are probably includes just celphones and tvs as can be seen in the FIFTH BAR GRAPH.
#
# 2. As seen in the THIRD BAR GRAPH, Brgy 58 has highest calamity-useful assets ownership score of approx. 0.85. This trend quickly dips with Brgy 99 which has a score of 0.5. This could point to Brgy 58 being having much more affluence than other brgys because their score indicates that people here almost have every kind of asset in our list, probably only missing one kind.
#
# 3. Based from the FOURTH BAR GRAPH, the lowest score in the top 10 is approx. 0.4 while the highest score in the bottom 10 is 0.25 which further supports the point made in number 1. The lowest score of approx. 0.14 belongs to brgy 176 which indicates that most respondents there only had one of the kinds of assets in our list which could be assumed to be mostly cellphones.
#
# Methodology:
# 1. Created a filtered dataframe copy of the original Main.CSV file that only contains the relevant variables for Score 2. These variables are INSERT THEM HERE.
# 2. Converted quantity responses in True or False responses by converting any response above 0 to 1. We only needed to know whether they have these assets or not, not how many of each kind of asset they have.
# 3. Summed the total of the kinds of assets owned per family.
# 4. Scored the family's asset ownership by getting the ratio of the family's kinds of owned assets over the total number of possible kinds of assets (7) in this scoring.
# 5. Grouped the families by baranggay and then computed for the mean asset ownership score.

# %%
dfScore2 = pd.DataFrame(arrayBrgyScores);
dfScore2.to_csv('BrgyScore2.csv', encoding='utf-8')

# The computed means for each baranggay's family college literacy rate is saved onto a CSV file for future use.
