# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as py
import matplotlib.pyplot as plot
import seaborn as sns
from matplotlib import rc

import matplotlib.mlab as mlab

# %%
dfScore1 = pd.read_csv('BrgyScore1.csv', low_memory=False);
dfScore2 = pd.read_csv('BrgyScore2.csv', low_memory=False);
dfScore3A = pd.read_csv('BrgyScore3A.csv', low_memory=False);
dfScore3B = pd.read_csv('BrgyScore3B.csv', low_memory=False);

# %%
print(dfScore1.columns.values)
print(dfScore2.columns.values)
print(dfScore3A.columns.values)
print(dfScore3B.columns.values)
# Out:
# ['brgy' 'score']
# ['brgy' 'asset_score']
# ['brgy' 'water_score']
# ['brgy' 'food_score']

# %%
dfMain = dfScore1
# Initiates our main dataframe for the final scoring by copying dfScore1

dfMain.rename(columns={'score':'literacy_score'}, inplace=True)
# Renames the 'score' column into 'literacy_score' to better identify it

dfMain = pd.merge(dfMain, dfScore2, on="brgy")
dfMain = pd.merge(dfMain, dfScore3A, on="brgy")
dfMain = pd.merge(dfMain, dfScore3B, on="brgy")
dfMain
# Out:
#      brgy  literacy_score  asset_score  water_score  food_score
# 0       1        0.566667     0.367347     1.000000    1.000000
# 1       2        0.536019     0.254915     0.036697    1.000000
# 2       3        0.416667     0.326531     0.285714    1.000000
# 3       4        0.349750     0.331754     0.440758    1.000000
# 4       5        0.509877     0.279907     0.089431    1.000000
# 5       6        0.487374     0.305394     0.173469    1.000000
# 6       7        0.447693     0.253821     0.274419    1.000000
# 7       8        0.419841     0.266129     0.185484    1.000000
# 8       9        0.775731     0.202116     0.251852    1.000000
# 9      10        0.501974     0.274510     0.124183    1.000000
# 10     11        0.523401     0.274809     0.045802    1.000000
# 11     12        0.452747     0.314721     0.395939    1.000000
# 12     13        0.417969     0.237006     0.066317    1.000000
# 13     14        0.493218     0.290816     0.195918    0.999854
# 14     15        0.679902     0.253348     0.007812    1.000000
# 15     16        0.405134     0.255411     0.037879    1.000000
# 16     18        0.622761     0.274031     0.252788    1.000000
# 17     19        0.531905     0.263536     0.301370    1.000000
# 18     20        0.639216     0.264286     0.357692    1.000000
# 19     21        0.517316     0.292359     0.875969    1.000000
# 20     22        0.448554     0.272109     0.800000    1.000000
# 21     23        0.474313     0.353630     0.502732    1.000000
# 22     24        0.452820     0.289710     0.101399    1.000000
# 23     25        0.429695     0.301905     0.013333    1.000000
# 24     26        0.478426     0.299003     0.063953    1.000000
# 25     27        0.559422     0.294974     0.046296    1.000000
# 26     28        0.430211     0.277666     0.018779    1.000000
# 27     30        0.516374     0.313804     0.511236    1.000000
# 28     31        0.483333     0.395604     0.538462    1.000000
# 29     33        0.670118     0.268685     0.867550    1.000000
# ..    ...             ...          ...          ...         ...
# 142   171        0.442456     0.304120     0.168375    1.000000
# 143   172        0.423288     0.313593     0.770175    0.999863
# 144   173        0.494410     0.303684     0.264151    1.000000
# 145   174        0.464032     0.290360     0.127371    1.000000
# 146   175        0.447993     0.342793     0.227991    0.999946
# 147   177        0.442803     0.303916     0.521236    0.999494
# 148   178        0.464540     0.267496     0.545295    1.000000
# 149   179        0.372845     0.333071     0.973865    0.999853
# 150   180        0.344021     0.288610     0.495450    1.000000
# 151   181        0.337648     0.291867     0.464419    1.000000
# 152   182        0.374377     0.306774     0.257935    1.000000
# 153   183        0.540399     0.326020     0.086811    1.000000
# 154   184        0.425118     0.273461     0.808229    1.000000
# 155   185        0.422559     0.299155     0.287634    1.000000
# 156   186        0.402615     0.287570     0.962038    0.999952
# 157   187        0.368326     0.331595     0.970803    1.000000
# 158   188        0.511799     0.292070     0.241779    1.000000
# 159   189        0.425748     0.272004     0.228407    0.999657
# 160   190        0.388625     0.283438     0.321713    0.999763
# 161   191        0.450146     0.269268     0.366801    1.000000
# 162   192        0.487987     0.282542     0.236550    1.000000
# 163   193        0.476868     0.281584     0.289123    1.000000
# 164   194        0.478987     0.283605     0.392385    1.000000
# 165   195        0.452615     0.291708     0.298951    1.000000
# 166   196        0.407561     0.278426     0.792517    1.000000
# 167   197        0.439905     0.277831     0.247679    1.000000
# 168   198        0.529976     0.292790     0.158019    1.000000
# 169   199        0.508304     0.287734     0.319192    1.000000
# 170   200        0.456457     0.327299     0.051370    1.000000
# 171   201        0.440028     0.340947     0.779070    0.999100
#
# [172 rows x 5 columns]
